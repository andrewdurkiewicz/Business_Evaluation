# %%
from importlib import reload
import integrators
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
reload(integrators)
m=1
t, y = integrators.integrate_newton(t_max=40,force=integrators.F_power,integrator=integrators.rk2,h=.01)

# %%
a = integrators.analyze_energies(t,y,integrators.U_power)

# %%
t, y = integrators.integrate_newton(t_max=40,force=integrators.F_power,integrator=integrators.rk4,h=.01)

# %%
a = integrators.analyze_energies(t,y,integrators.U_power)
plt.figure()
d = plt.subplot(2, 1, 1)
d.plot(y[:,0],m*y[:,1])
d.set_ylabel("y")
d.set_xlabel("x")
